# %% [markdown]
# ### Mensagens | 16/07

# %%
from datetime import datetime

# %%
caminho_arquivo = "transpor_chat.txt"
data_desejada = "16/07/25"

# %%
with open(caminho_arquivo, 'r') as arquivo:
    for linha in arquivo:
        if linha.startswith('[16/07/25'):
            # Exemplo: [16/07/25, 10:15] Kaê: Já fiz a entrega.
            timestamp, restante = linha.split('] ', 1)
            timestamp = timestamp.strip('[')
            autor, mensagem = restante.split(': ', 1)
            print(f"{autor.strip()}: {mensagem.strip()}")

            # palavras_chave = ["extensão", "reunião", "ufms", "demandas", "pautas", "transpor", "coletivo", "apoio"]

            # if any(palavra in mensagem.lower() for palavra in palavras_chave):
            #     print(mensagem)
# Out:
# Gal: 📅 PROGRAMAÇÃO SEMANAL
# ~ Fê: Alguém aí faz nutrição?
# ~ Fê: (temos q escolher um tutor)
# ~ Giulia Rita 🪆: amoras
# ~ Giulia Rita 🪆: como tá a situacao do transpor hoje? tipo, tá formalizado de alguma forma?
# ~ Giulia Rita 🪆: tipo, com quem eu falo p/ ter mais infos sobre o coletivo?
# ~ Ariel: Não sei mana, pq já faz um tempo que não tem reunião pra tratar das nossas demandas
# ~ Ariel: Mas acho que com a Gal
# ~ Giulia Rita 🪆: Gal ja saiu da ufms ha tempos, migo. mora nem em CG mais kkkk
# ~ Ariel: Mds kkkkk, eu nem tava sabendo
# Gal: Amiga acredito que não está mais institucionalmente registrado
# Gal: Talvez o @556792843391 saiba responder essa situação
# Gal: Mas não sabemos até que ponto é interessante nos regularizarmos na UFMS como coletivo de bovo
# Gal: Pq sinceramente não serviu pra quase nada
# ~ Roni: Participamos da recepção de calouros em março como coletivo, mas também foi só
# ...
